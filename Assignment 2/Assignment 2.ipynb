# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install mmdet
# Out:
# ...
#   Using cached mmdet-2.26.0-py3-none-any.whl (1.4 MB)
# ...
#   Using cached pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
# Failed to build pycocotools
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\users\chin\desktop\stuff\projects\walnut-ai-assignment\venv\scripts\python.exe' 'c:\users\chin\desktop\stuff\projects\walnut-ai-assignment\venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\Chin\AppData\Local\Temp\tmpkatp8r3x'
#        cwd: C:\Users\Chin\AppData\Local\Temp\pip-install-vs0pxi5p\pycocotools_03e6f0478ee748cfa7b78ebcc7aff7e2
#   Complete output (23 lines):
#   running bdist_wheel
#   running build
# ...

# %% [markdown]
# ## Installing Dependencies for camelot
# https://camelot-py.readthedocs.io/en/master/user/install-deps.html

# %% [markdown]
# ## Installing Dependencies for Cascade_Tabnet

# %%
# !{sys.executable} -m pip install torch==1.4.0+cu100 torchvision==0.5.0+cu100 -f https://download.pytorch.org/whl/cu100/torch_stable.html
# !{sys.executable} -m pip install -q mmcv terminaltables
# !git clone --branch v1.2.0 'http://github.com/open-mmlab/mmdetection.git'
# %cd "mmdetection"
# !{sys.executable} -m pip install -r "requirements/optional.txt"
# !{sys.executable} setup.py install
# !python setup.py develop
# !pip install -r {"requirements.txt"}
# !pip install pillow==6.2.1
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Chin\Desktop\stuff\Projects\walnut-ai-assignment\Assignment 2\mmdetection\setup.py", line 222, in <module>
#     make_cuda_ext(
#   File "C:\Users\Chin\Desktop\stuff\Projects\walnut-ai-assignment\Assignment 2\mmdetection\setup.py", line 94, in make_cuda_ext
#     raise EnvironmentError('CUDA is required to compile MMDetection!')
# OSError: CUDA is required to compile MMDetection!

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
import torch
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import torch
# ----> 2 from mmdet.apis import init_detector, inference_detector, show_result_pyplot
#
# ModuleNotFoundError: No module named 'mmdet'

# %% [markdown]
# ## Reading PDF

# %%
filename = "../keppel-corporation-limited-annual-report-2018.pdf"

# %%
import camelot

# %%
tables = camelot.read_pdf(filename,pages='69', flavor='stream')
tables
# Out:
# <TableList n=2>

# %%
tables[0].df
# Out:
#                                                    0  \
# 0           in FY 2018, as well as the attendance of
# 1               each Board member at these meetings,
# 2                  are disclosed in the table below.
# 3
# 4        If a director were unable to attend a board
# 5           or board committee meeting, he/she would
# 6     still receive all the papers and materials for
# 7           discussion at that meeting. He/she would
# 8             review them and advise the Chairman or
# 9                board committee chairman of his/her
# 10           views and comments on the matters to be
# 11         discussed so that they may be conveyed to
# 12                     other members at the meeting.
# 13
# 14         Internal Limits of Authority: The Company
# 15     has adopted internal guidelines setting forth
# 16        matters that require board approval. Under
# 17      these guidelines, all transactions exceeding
# ...

# %%
df = tables[1].df
df
# Out:
#                                               0               1      2  \
# 0   Board and Committee Meetings and Attendance
# 1
# 2                                                Board Meetings  Audit
# 3                                 Lee Boon Yang              11      –
# 4                                  Loh Chin Hua              11      –
# 5                                  Tow Heng Tan               8      –
# 6                           Alvin Yeo Khirn Hai               9      5
# 7                                    Tan Ek Kia               9      5
# 8                                    Danny Teoh              10      5
# 9                              Tan Puay Chiang1              10      –
# 10                                Till Vestring              11      –
# 11                                 Veronica Eng              11      5
# 12                       Jean-François Manzoni2      3 out of 3      –
# ...

# %%
title = df[0][0]
title
# Out:
# 'Board and Committee Meetings and Attendance'

# %%
df.drop(0)
# Out:
#                          0               1      2           3  \
# 1
# 2                           Board Meetings  Audit  Nomination
# 3            Lee Boon Yang              11      –           3
# 4             Loh Chin Hua              11      –           –
# 5             Tow Heng Tan               8      –           3
# 6      Alvin Yeo Khirn Hai               9      5           1
# 7               Tan Ek Kia               9      5           –
# 8               Danny Teoh              10      5           –
# 9         Tan Puay Chiang1              10      –           3
# 10           Till Vestring              11      –           3
# 11            Veronica Eng              11      5           –
# 12  Jean-François Manzoni2      3 out of 3      –           –
# 13    No. of Meetings Held              11      5           3
#
#                            4       5     6
# 1   Board Committee Meetings
# 2               Remuneration  Safety  Risk
# ...

# %%
df2 =
